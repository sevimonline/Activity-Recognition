# %% [markdown]
# # IMPORT LIBRARY

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# # DATA IMPORT

# %%
columnname = pd.read_excel("features.xlsx")
column = columnname["degiskenismi"]

# %%
x_train = pd.read_excel("x_train.xlsx", names = column)
x_test = pd.read_excel("x_test.xlsx", names = column)
y_train = pd.read_excel("y_train.xlsx", names = ["activity"]) -1
y_test = pd.read_excel("y_test.xlsx", names = ["activity"]) -1

# %%
subject_test = pd.read_excel("subject_test.xlsx", names = ["subject"])
subject_train = pd.read_excel("subject_train.xlsx", names = ["subject"])

# %%
train = pd.concat([x_train,y_train,subject_train], axis = 1)

# %%
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0               0.28              -0.02              -0.12             -1.00
# 1               0.28              -0.02              -0.11             -1.00
# 2               0.28              -0.03              -0.12             -1.00
# 3               0.28              -0.02              -0.12             -1.00
# 4               0.28              -0.01              -0.11             -1.00
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0             -0.98             -0.96             -1.00             -0.97
# 1             -0.97             -0.98             -1.00             -0.96
# 2             -0.98             -0.99             -1.00             -0.98
# 3             -0.98             -0.99             -1.00             -0.98
# 4             -0.99             -1.00             -1.00             -0.99
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0             -0.96             -0.94  ...                            -0.86
# 1             -0.98             -0.94  ...                            -0.76
# 2             -0.99             -0.94  ...                            -0.48
# 3             -0.99             -0.94  ...                            -0.70
# 4             -1.00             -0.94  ...                            -0.84
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                         0.05                                 -0.01
# 1                        -0.12                                  0.18
# 2                        -0.04                                 -0.01
# 3                         0.12                                  0.12
# 4                         0.08                                 -0.14
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                             -0.73                                  0.70
# 1                              0.10                                  0.81
# 2                              0.64                                 -0.49
# 3                              0.69                                 -0.62
# 4                              0.28                                 -0.37
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  activity  \
# 0                 -0.84                  0.18                 -0.05         4
# 1                 -0.85                  0.18                 -0.05         4
# 2                 -0.85                  0.18                 -0.05         4
# 3                 -0.85                  0.19                 -0.04         4
# 4                 -0.85                  0.18                 -0.04         4
#
#    subject
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#
# [5 rows x 563 columns]

# %%
test = pd.concat([x_test,y_test,subject_test], axis = 1)

# %%
# import libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

# %%
plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='activity', data = train)
plt.show()

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.activity)
plt.xticks(rotation=90)
plt.show()

# %%
columns = train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

train.columns = columns
test.columns = columns

test.columns
# Out:
# Index(['tBodyAccmeanX', 'tBodyAccmeanY', 'tBodyAccmeanZ', 'tBodyAccstdX',
#        'tBodyAccstdY', 'tBodyAccstdZ', 'tBodyAccmadX', 'tBodyAccmadY',
#        'tBodyAccmadZ', 'tBodyAccmaxX',
#        ...
#        'fBodyBodyGyroJerkMagkurtosis', 'angletBodyAccMeangravity',
#        'angletBodyAccJerkMeangravityMean', 'angletBodyGyroMeangravityMean',
#        'angletBodyGyroJerkMeangravityMean', 'angleXgravityMean',
#        'angleYgravityMean', 'angleZgravityMean', 'activity', 'subject'],
#       dtype='object', length=563)

# %% [markdown]
# ### Save this dataframe in a csv files ###

# %%
train.to_csv('f_train.csv', index=False)
test.to_csv('f_test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis #

# %% [markdown]
# ## 1. Featuring Engineering from Domain Knowledge

# %%
    # Static and Dynamic Activities

        # In static activities (sit, stand, lie down) motion information will not be very useful.
        # In the dynamic activities (Walking, WalkingUpstairs,WalkingDownstairs) motion info will be significant.

# %% [markdown]
# ## 2. Stationary and Moving activities are completely different

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(train, hue='activity', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False)\
    .add_legend()
plt.annotate("Stationary Activities", xy=(-0.956,17), xytext=(-0.9, 23), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))

plt.annotate("Moving Activities", xy=(0,3), xytext=(0.2, 9), size=20,\
            va='center', ha='left',\
            arrowprops=dict(arrowstyle="simple",connectionstyle="arc3,rad=0.1"))
plt.show()

# %%
#0 WALKING      -
#1 WALKING_UPSTAIRS     
#2 WALKING_DOWNSTAIRS
#3 SITTING 
#4 STANDING            
#5 LAYING

# %%
## MOVING ACTIVIES
train.activity = train.activity.replace(0,"WALKING")
train.activity = train.activity.replace(1,"WALKING_UPSTAIRS")
train.activity = train.activity.replace(2,"WALKING_DOWNSTAIRS")

test.activity = test.activity.replace(0,"WALKING")
test.activity = test.activity.replace(1,"WALKING_UPSTAIRS")
test.activity = test.activity.replace(2,"WALKING_DOWNSTAIRS")


## STATIONARY ACTIVITIES
train.activity = train.activity.replace(3,"SITTING")
train.activity = train.activity.replace(4,"STANDING")
train.activity = train.activity.replace(5,"LAYING")

test.activity = test.activity.replace(3,"SITTING")
test.activity = test.activity.replace(4,"STANDING")
test.activity = test.activity.replace(5,"LAYING")

# %%
train.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0               0.28              -0.02              -0.12             -1.00
# 1               0.28              -0.02              -0.11             -1.00
# 2               0.28              -0.03              -0.12             -1.00
# 3               0.28              -0.02              -0.12             -1.00
# 4               0.28              -0.01              -0.11             -1.00
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0             -0.98             -0.96             -1.00             -0.97
# 1             -0.97             -0.98             -1.00             -0.96
# 2             -0.98             -0.99             -1.00             -0.98
# 3             -0.98             -0.99             -1.00             -0.98
# 4             -0.99             -1.00             -1.00             -0.99
#
#    tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  fBodyBodyGyroJerkMag-kurtosis()  \
# 0             -0.96             -0.94  ...                            -0.86
# 1             -0.98             -0.94  ...                            -0.76
# 2             -0.99             -0.94  ...                            -0.48
# 3             -0.99             -0.94  ...                            -0.70
# 4             -1.00             -0.94  ...                            -0.84
#
#    angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 0                         0.05                                 -0.01
# 1                        -0.12                                  0.18
# 2                        -0.04                                 -0.01
# 3                         0.12                                  0.12
# 4                         0.08                                 -0.14
#
#    angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 0                             -0.73                                  0.70
# 1                              0.10                                  0.81
# 2                              0.64                                 -0.49
# 3                              0.69                                 -0.62
# 4                              0.28                                 -0.37
#
#    angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  activity  \
# 0                 -0.84                  0.18                 -0.05  STANDING
# 1                 -0.85                  0.18                 -0.05  STANDING
# 2                 -0.85                  0.18                 -0.05  STANDING
# 3                 -0.85                  0.19                 -0.04  STANDING
# 4                 -0.85                  0.18                 -0.04  STANDING
#
#    subject
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#
# [5 rows x 563 columns]

# %%
# for plotting purposes taking datapoints of each activity to a different dataframe
df1 = train[train['activity']==0]
df2 = train[train['activity']==1]
df3 = train[train['activity']==2]
df4 = train[train['activity']==3]
df5 = train[train['activity']==4]
df6 = train[train['activity']==5]

# %%
plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
plt.title("Static Activities(closer view)")
sns.distplot(train[train["activity"]=="SITTING"]['tBodyAccMagmean'],hist = False, label = 'Sitting')
sns.distplot(train[train["activity"]=="STANDING"]['tBodyAccMagmean'],hist = False,label = 'Standing')
sns.distplot(train[train["activity"]=="LAYING"]['tBodyAccMagmean'],hist = False, label = 'Laying')
plt.axis([-1.02, -0.5, 0, 35])
plt.subplot(1,2,2)
plt.title("Dynamic Activities(closer view)")
sns.distplot(train[train["activity"]=="WALKING"]['tBodyAccMagmean'],hist = False, label = 'Sitting')
sns.distplot(train[train["activity"]=="WALKING_DOWNSTAIRS"]['tBodyAccMagmean'],hist = False,label = 'Standing')
sns.distplot(train[train["activity"]=="WALKING_UPSTAIRS"]['tBodyAccMagmean'],hist = False, label = 'Laying')
# Out:
# <AxesSubplot:title={'center':'Dynamic Activities(closer view)'}, xlabel='tBodyAccMagmean', ylabel='Density'>

# %% [markdown]
# ## 3. Magnitude of an acceleration can saperate it well

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='activity', y='tBodyAccMagmean',data=train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Observations:
#
# ### If tAccMean is < -0.8 then the Activities are either Standing or Sitting or Laying.
# ### If tAccMean is > -0.6 then the Activities are either Walking or WalkingDownstairs or WalkingUpstairs.
# ### If tAccMean > 0.0 then the Activity is WalkingDownstairs.
# ### We can classify 75% the Acitivity labels with some errors.

# %% [markdown]
# ## 4. Position of GravityAccelerationComponants also matters

# %%
sns.boxplot(x='activity', y='angleXgravityMean', data=train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# ## Observations:
#
# ### If angleX,gravityMean > 0 then Activity is Laying.
# ### We can classify all datapoints belonging to Laying activity with just a single if else statement.

# %%
sns.boxplot(x='activity', y='angleYgravityMean', data = train, showfliers=False)
plt.title('Angle between Y-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.axhline(y=-0.22, xmin=0.1, xmax=0.8, dashes=(5,3), c='m')
plt.show()

# %% [markdown]
# # Apply t-sne on the data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Here we will see these datapoints in 2 dimensions and try to observe the behaviour of the datapoints

# %%
# performs t-sne with different perplexity values and their repective plots..

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'activity'], axis=1)
y_pre_tsne = train['activity']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[5,10,20])
# Out:
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7351 samples in 0.010s...
# [t-SNE] Computed neighbors for 7351 samples in 2.768s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7351
# [t-SNE] Computed conditional probabilities for sample 2000 / 7351
# [t-SNE] Computed conditional probabilities for sample 3000 / 7351
# [t-SNE] Computed conditional probabilities for sample 4000 / 7351
# [t-SNE] Computed conditional probabilities for sample 5000 / 7351
# [t-SNE] Computed conditional probabilities for sample 6000 / 7351
# [t-SNE] Computed conditional probabilities for sample 7000 / 7351
# [t-SNE] Computed conditional probabilities for sample 7351 / 7351
# [t-SNE] Mean sigma: 0.961422
# [t-SNE] Computed conditional probabilities in 0.060s
# [t-SNE] Iteration 50: error = 114.0259552, gradient norm = 0.0222436 (50 iterations in 3.897s)
# [t-SNE] Iteration 100: error = 97.3903503, gradient norm = 0.0155731 (50 iterations in 3.128s)
# [t-SNE] Iteration 150: error = 93.0583191, gradient norm = 0.0090796 (50 iterations in 2.920s)
# [t-SNE] Iteration 200: error = 91.0820694, gradient norm = 0.0073601 (50 iterations in 2.648s)
# [t-SNE] Iteration 250: error = 89.9177856, gradient norm = 0.0058396 (50 iterations in 2.570s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.917786
# [t-SNE] Iteration 300: error = 3.5705090, gradient norm = 0.0014608 (50 iterations in 2.534s)
# [t-SNE] Iteration 350: error = 2.8132062, gradient norm = 0.0007452 (50 iterations in 2.647s)
# [t-SNE] Iteration 400: error = 2.4328494, gradient norm = 0.0005295 (50 iterations in 2.559s)
# [t-SNE] Iteration 450: error = 2.2152870, gradient norm = 0.0004040 (50 iterations in 2.630s)
# [t-SNE] Iteration 500: error = 2.0707054, gradient norm = 0.0003315 (50 iterations in 2.605s)
# [t-SNE] Iteration 550: error = 1.9656916, gradient norm = 0.0002823 (50 iterations in 2.621s)
# [t-SNE] Iteration 600: error = 1.8846109, gradient norm = 0.0002443 (50 iterations in 2.590s)
# [t-SNE] Iteration 650: error = 1.8195344, gradient norm = 0.0002196 (50 iterations in 2.551s)
# [t-SNE] Iteration 700: error = 1.7657502, gradient norm = 0.0001978 (50 iterations in 2.807s)
# [t-SNE] Iteration 750: error = 1.7205269, gradient norm = 0.0001784 (50 iterations in 2.589s)
# [t-SNE] Iteration 800: error = 1.6815473, gradient norm = 0.0001665 (50 iterations in 2.647s)
# [t-SNE] Iteration 850: error = 1.6478256, gradient norm = 0.0001554 (50 iterations in 2.708s)
# [t-SNE] Iteration 900: error = 1.6185360, gradient norm = 0.0001414 (50 iterations in 2.759s)
# [t-SNE] Iteration 950: error = 1.5924847, gradient norm = 0.0001322 (50 iterations in 2.624s)
# [t-SNE] Iteration 1000: error = 1.5689812, gradient norm = 0.0001251 (50 iterations in 2.672s)
# [t-SNE] KL divergence after 1000 iterations: 1.568981
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7351 samples in 0.015s...
# [t-SNE] Computed neighbors for 7351 samples in 2.838s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7351
# [t-SNE] Computed conditional probabilities for sample 2000 / 7351
# [t-SNE] Computed conditional probabilities for sample 3000 / 7351
# [t-SNE] Computed conditional probabilities for sample 4000 / 7351
# [t-SNE] Computed conditional probabilities for sample 5000 / 7351
# [t-SNE] Computed conditional probabilities for sample 6000 / 7351
# [t-SNE] Computed conditional probabilities for sample 7000 / 7351
# [t-SNE] Computed conditional probabilities for sample 7351 / 7351
# [t-SNE] Mean sigma: 1.133804
# [t-SNE] Computed conditional probabilities in 0.136s
# [t-SNE] Iteration 50: error = 105.9837189, gradient norm = 0.0191186 (50 iterations in 4.732s)
# [t-SNE] Iteration 100: error = 91.0961609, gradient norm = 0.0101134 (50 iterations in 3.517s)
# [t-SNE] Iteration 150: error = 87.3623581, gradient norm = 0.0052410 (50 iterations in 3.216s)
# [t-SNE] Iteration 200: error = 86.0194550, gradient norm = 0.0037456 (50 iterations in 3.083s)
# [t-SNE] Iteration 250: error = 85.2975845, gradient norm = 0.0033610 (50 iterations in 2.999s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.297585
# [t-SNE] Iteration 300: error = 3.1235507, gradient norm = 0.0013744 (50 iterations in 2.695s)
# [t-SNE] Iteration 350: error = 2.4849963, gradient norm = 0.0006489 (50 iterations in 2.615s)
# [t-SNE] Iteration 400: error = 2.1682208, gradient norm = 0.0004234 (50 iterations in 3.137s)
# [t-SNE] Iteration 450: error = 1.9851333, gradient norm = 0.0003128 (50 iterations in 2.692s)
# [t-SNE] Iteration 500: error = 1.8674966, gradient norm = 0.0002539 (50 iterations in 4.287s)
# [t-SNE] Iteration 550: error = 1.7844368, gradient norm = 0.0002125 (50 iterations in 2.888s)
# [t-SNE] Iteration 600: error = 1.7223084, gradient norm = 0.0001829 (50 iterations in 3.296s)
# [t-SNE] Iteration 650: error = 1.6738503, gradient norm = 0.0001589 (50 iterations in 4.246s)
# [t-SNE] Iteration 700: error = 1.6344910, gradient norm = 0.0001429 (50 iterations in 3.799s)
# [t-SNE] Iteration 750: error = 1.6021528, gradient norm = 0.0001292 (50 iterations in 3.001s)
# [t-SNE] Iteration 800: error = 1.5747484, gradient norm = 0.0001184 (50 iterations in 3.247s)
# [t-SNE] Iteration 850: error = 1.5512276, gradient norm = 0.0001095 (50 iterations in 3.395s)
# [t-SNE] Iteration 900: error = 1.5308855, gradient norm = 0.0001046 (50 iterations in 2.940s)
# [t-SNE] Iteration 950: error = 1.5134995, gradient norm = 0.0000970 (50 iterations in 3.653s)
# [t-SNE] Iteration 1000: error = 1.4983249, gradient norm = 0.0000919 (50 iterations in 3.246s)
# [t-SNE] KL divergence after 1000 iterations: 1.498325
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7351 samples in 0.012s...
# [t-SNE] Computed neighbors for 7351 samples in 3.495s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7351
# [t-SNE] Computed conditional probabilities for sample 2000 / 7351
# [t-SNE] Computed conditional probabilities for sample 3000 / 7351
# [t-SNE] Computed conditional probabilities for sample 4000 / 7351
# [t-SNE] Computed conditional probabilities for sample 5000 / 7351
# [t-SNE] Computed conditional probabilities for sample 6000 / 7351
# [t-SNE] Computed conditional probabilities for sample 7000 / 7351
# [t-SNE] Computed conditional probabilities for sample 7351 / 7351
# [t-SNE] Mean sigma: 1.274318
# [t-SNE] Computed conditional probabilities in 0.219s
# [t-SNE] Iteration 50: error = 97.1448288, gradient norm = 0.0241472 (50 iterations in 6.323s)
# [t-SNE] Iteration 100: error = 83.8989487, gradient norm = 0.0060457 (50 iterations in 4.152s)
# [t-SNE] Iteration 150: error = 81.9353333, gradient norm = 0.0042664 (50 iterations in 3.431s)
# [t-SNE] Iteration 200: error = 81.2091217, gradient norm = 0.0027731 (50 iterations in 3.217s)
# [t-SNE] Iteration 250: error = 80.8029099, gradient norm = 0.0026794 (50 iterations in 3.287s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.802910
# [t-SNE] Iteration 300: error = 2.7017469, gradient norm = 0.0013000 (50 iterations in 3.051s)
# [t-SNE] Iteration 350: error = 2.1670666, gradient norm = 0.0005758 (50 iterations in 3.042s)
# [t-SNE] Iteration 400: error = 1.9162033, gradient norm = 0.0003475 (50 iterations in 2.998s)
# [t-SNE] Iteration 450: error = 1.7695096, gradient norm = 0.0002482 (50 iterations in 3.051s)
# [t-SNE] Iteration 500: error = 1.6755738, gradient norm = 0.0001907 (50 iterations in 3.297s)
# [t-SNE] Iteration 550: error = 1.6114200, gradient norm = 0.0001568 (50 iterations in 3.030s)
# [t-SNE] Iteration 600: error = 1.5650353, gradient norm = 0.0001349 (50 iterations in 3.063s)
# [t-SNE] Iteration 650: error = 1.5299616, gradient norm = 0.0001179 (50 iterations in 3.045s)
# [t-SNE] Iteration 700: error = 1.5024409, gradient norm = 0.0001065 (50 iterations in 3.008s)
# [t-SNE] Iteration 750: error = 1.4806356, gradient norm = 0.0000948 (50 iterations in 3.182s)
# [t-SNE] Iteration 800: error = 1.4631336, gradient norm = 0.0000907 (50 iterations in 3.090s)
# [t-SNE] Iteration 850: error = 1.4496868, gradient norm = 0.0000843 (50 iterations in 3.092s)
# [t-SNE] Iteration 900: error = 1.4386865, gradient norm = 0.0000791 (50 iterations in 3.102s)
# [t-SNE] Iteration 950: error = 1.4289830, gradient norm = 0.0000740 (50 iterations in 3.156s)
# [t-SNE] Iteration 1000: error = 1.4201759, gradient norm = 0.0000734 (50 iterations in 3.113s)
# [t-SNE] KL divergence after 1000 iterations: 1.420176
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
